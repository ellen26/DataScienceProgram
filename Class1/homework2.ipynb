# %%
import pandas as pd
data = pd.read_csv("loans_income.csv")

# %%
import numpy as np

# %%
data
# Out:
#             x
# 0       67000
# 1       52000
# 2      100000
# 3       78762
# 4       37041
# 5       33000
# 6       38500
# 7       85000
# 8      120000
# 9       57000
# 10      61279
# 11      60000
# 12      57750
# 13      65000
# 14      90000
# 15      36000
# 16     150000
# 17      33000
# 18      53000
# 19     165000
# 20      30000
# 21      80000
# 22      40000
# 23      80000
# 24      70000
# 25      60000
# 26      78000
# 27      23998
# 28      36000
# 29      80000
# ...       ...
# 49970   66500
# 49971  150000
# 49972   48602
# 49973   34000
# 49974  115000
# 49975   70000
# 49976   73000
# 49977   80000
# 49978   50000
# 49979   68000
# 49980  115000
# 49981   92500
# 49982   85000
# 49983   54000
# 49984   65000
# 49985   95000
# 49986  111000
# 49987   58000
# 49988   60000
# 49989  170000
# 49990  118000
# 49991   70000
# 49992  104000
# 49993  110000
# 49994   90000
# 49995   40000
# 49996   54000
# 49997   50000
# 49998   82000
# 49999   70000
#
# ...

# %%
sample = data.sample(n=10000)
sample #here we draw 10000 samples
# Out:
#             x
# 49830   75000
# 57      23000
# 10205   80000
# 31488  155000
# 3373    69000
# 484    120000
# 3189    50000
# 4469    35000
# 9245    52000
# 26463   83000
# 2727    50000
# 14698   64944
# 13647   40000
# 8176    53000
# 11288  120000
# 5828    34840
# 16676   77000
# 35491   95004
# 38870   83000
# 5800    60000
# 42232   28000
# 29505   85000
# 33062   97000
# 44918   21000
# 22369  115000
# 14081   16000
# 49173   48000
# 25919   65000
# 47781   72155
# 32587   65000
# ...       ...
# 25159   89000
# 45009   58000
# 26912   42440
# 5239    47000
# 30395   69000
# 41058   53560
# 14376   80000
# 38190  115500
# 22482   72000
# 36580  110000
# 27114   90000
# 45479   93000
# 45575  115000
# 18196   26500
# 1231   102300
# 33781   46000
# 31395  100000
# 8431    80000
# 41842   78000
# 34420   87699
# 23171   98000
# 41396   26500
# 16063   83000
# 15016   95000
# 31806  110000
# 19248   90000
# 45409   84000
# 7500    27000
# 29327   36000
# 481     95000
#
# ...

# %%
sample10 = data.sample(n=10)
pd.plotting.bootstrap_plot(data, size=10)

# %%
sample10 = data.sample(n=10)
pd.plotting.bootstrap_plot(data, size=50)

# %%
sample10 = data.sample(n=10)
pd.plotting.bootstrap_plot(data, size=100)

# %%
sample10 = data.sample(n=10)
pd.plotting.bootstrap_plot(data, size=1000)

# %%
sample100 = data.sample(n=100)
pd.plotting.bootstrap_plot(data, size=10)

# %%
sample100 = data.sample(n=100)
pd.plotting.bootstrap_plot(data, size=50)

# %%
sample100 = data.sample(n=100)
pd.plotting.bootstrap_plot(data, size=100)

# %%
sample100 = data.sample(n=100)
pd.plotting.bootstrap_plot(data, size=1000)
